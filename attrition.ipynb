# %% [markdown]
# ## Part 1: Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras import layers

#  Import and read the attrition data
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  ...  PerformanceRating RelationshipSatisfaction  \
# 0               3  ...                  3                        1
# 1               2  ...                  4                        4
# 2               2  ...                  3                        2
# 3               3  ...                  3                        3
# 4               3  ...                  3                        4
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                 8                      0               1
# 1                 1                10                      3               3
# 2                 0                 7                      3               3
# 3                 0                 8                      3               3
# 4                 1                 6                      3               3
#
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                   4                        0
# 1              10                   7                        1
# 2               0                   0                        0
# 3               8                   7                        3
# 4               2                   2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 27 columns]

# %%
# Determine the number of unique values in each column.
attrition_df.nunique()
# Out:
# Age                         43
# Attrition                    2
# BusinessTravel               3
# Department                   3
# DistanceFromHome            29
# Education                    5
# EducationField               6
# EnvironmentSatisfaction      4
# HourlyRate                  71
# JobInvolvement               4
# JobLevel                     5
# JobRole                      9
# JobSatisfaction              4
# MaritalStatus                3
# NumCompaniesWorked          10
# OverTime                     2
# PercentSalaryHike           15
# PerformanceRating            2
# RelationshipSatisfaction     4
# StockOptionLevel             4
# TotalWorkingYears           40
# TrainingTimesLastYear        7
# WorkLifeBalance              4
# YearsAtCompany              37
# YearsInCurrentRole          19
# YearsSinceLastPromotion     16
# YearsWithCurrManager        18
# dtype: int64

# %%
attrition_df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EnvironmentSatisfaction      int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# NumCompaniesWorked           int64
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %%
# Create y_df with the Attrition and Department columns
y_df = attrition_df[['Attrition', 'Department']]
print(y_df['Attrition'].value_counts())
print(y_df['Department'].value_counts())
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
# Create a list of at least 10 column names to use as X data
X_data = ['Education','Age','DistanceFromHome','JobSatisfaction','OverTime','StockOptionLevel','WorkLifeBalance','YearsAtCompany', 'YearsSinceLastPromotion','NumCompaniesWorked']


# Create X_df using your selected columns
X_df = attrition_df[X_data]

# Show the data types for X_df
X_df.dtypes
# Out:
# Education                   int64
# Age                         int64
# DistanceFromHome            int64
# JobSatisfaction             int64
# OverTime                   object
# StockOptionLevel            int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# YearsSinceLastPromotion     int64
# NumCompaniesWorked          int64
# dtype: object

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, random_state=10)

# %%
X_train['OverTime'].value_counts()
# Out:
# OverTime
# No     791
# Yes    311
# Name: count, dtype: int64

# %%
# Convert your X data to numeric data types however you see fit
# Add new code cells as necessary
X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)
# transform True to 1 and false to 0
X_train = X_train.astype(int)
X_test = X_test.astype(int)

# %%
# Convert your X data to numeric data types however you see fit
# Add new code cells as necessary

# %%
# Create a StandardScaler
scaler = StandardScaler()

# Fit the StandardScaler to the training data
X_scaler = scaler.fit(X_train)

# Scale the training and testing data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create a OneHotEncoder for the Department column
from sklearn.preprocessing import OneHotEncoder
department_encoder = OneHotEncoder(drop=None, handle_unknown='ignore',sparse_output=False)

# Fit the encoder to the training data
department_encoder.fit(np.array(y_train['Department']).reshape(-1, 1))

# Create two new variables by applying the encoder to the training and testing data
dept_y_train_encoded = department_encoder.transform(np.array(y_train['Department']).reshape(-1, 1))
dept_y_test_encoded = department_encoder.transform(np.array(y_test['Department']).reshape(-1, 1))
dept_y_test_encoded
# Out:
# array([[0., 1., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.],
#        ...,
#        [0., 1., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
# Create a OneHotEncoder for the Attrition column
attrition_encoder = OneHotEncoder(drop=None, handle_unknown='ignore',sparse_output=False)

# Fit the encoder to the training data
attrition_encoder.fit(np.array(y_train['Attrition']).reshape(-1, 1))

# Create two new variables by applying the encoder
# to the training and testing data
attr_y_train_encoded = attrition_encoder.transform(np.array(y_train['Attrition']).reshape(-1, 1))
attr_y_test_encoded = attrition_encoder.transform(np.array(y_test['Attrition']).reshape(-1, 1))

# %%
attr_y_train_encoded.shape[1]
# Out:
# 2

# %% [markdown]
# ## Create, Compile, and Train the Model

# %%
# Find the number of columns in the X training data
cols = X_train.shape[1]

# Create the input layer
input = layers.Input(shape=(cols, ), name='input')


# Create at least two shared layers
shared1 = layers.Dense(64, activation="relu",name='shared_layer_1')(input)
shared2 = layers.Dense(128, activation="relu",name='shared_layer_2')(shared1)

# %%
# Create a branch for Department
# with a hidden layer and an output layer

department_input = layers.Dense(32, activation='relu')(shared2)

# Create the hidden layer
#hidden_dept= layers.Dense(64, activation='relu')(department_input)


# Create the output layer
department_output = layers.Dense(dept_y_train_encoded.shape[1], activation='sigmoid', name = "dept_output")(department_input)

# %%
# Create a branch for Attrition
# with a hidden layer and an output layer
attrition_input = layers.Dense(64, activation='relu')(shared2)


# Create the hidden layer
#hidden_attr= layers.Dense(64, activation='relu')(attrition_input)
#hidden_attr= layers.Dense(cols, activation='relu')(attrition_input)

# Create the output layer
#attrition_output = layers.Dense(2, activation='softmax', name = "attr_output")(hidden_attr)
attrition_output = layers.Dense(attr_y_train_encoded.shape[1], activation='sigmoid', name = "attr_output")(attrition_input)

# %%
# Create the model
model = Model(inputs=input, outputs=[ department_output, attrition_output])

# Compile the model
model.compile(optimizer='adam', loss={
        'dept_output': 'categorical_crossentropy',
              'attr_output': 'binary_crossentropy'},
              metrics=[['accuracy'], ['accuracy']])

# Summarize the model
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)        │ (None, 11)             │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ shared_layer_1 (Dense)    │ (None, 64)             │            768 │ input[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ shared_layer_2 (Dense)    │ (None, 128)            │          8,320 │ shared_layer_1[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 32)             │          4,128 │ shared_layer_2[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 64)             │          8,256 │ shared_layer_2[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dept_output (Dense)       │ (None, 3)              │             99 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ attr_output (Dense)       │ (None, 2)              │            130 │ dense_3[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 21,701 (84.77 KB)
#  Trainable params: 21,701 (84.77 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model with the training data
model.fit(X_train_scaled, {"dept_output": dept_y_train_encoded, "attr_output" : attr_y_train_encoded}, epochs=100, batch_size=16)
# Out:
# Epoch 1/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - attr_output_accuracy: 0.8571 - dept_output_accuracy: 0.6322 - loss: 1.3853
# Epoch 2/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.8376 - dept_output_accuracy: 0.6386 - loss: 1.1754
# Epoch 3/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.8361 - dept_output_accuracy: 0.6761 - loss: 1.1570
# Epoch 4/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.8568 - dept_output_accuracy: 0.6689 - loss: 1.0924
# Epoch 5/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attr_output_accuracy: 0.8683 - dept_output_accuracy: 0.6929 - loss: 1.0228
# Epoch 6/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.8715 - dept_output_accuracy: 0.6779 - loss: 1.0323
# Epoch 7/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.8693 - dept_output_accuracy: 0.6703 - loss: 1.0489
# Epoch 8/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.8758 - dept_output_accuracy: 0.7007 - loss: 0.9771
# Epoch 9/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attr_output_accuracy: 0.8738 - dept_output_accuracy: 0.6774 - loss: 1.0008
# Epoch 10/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.8797 - dept_output_accuracy: 0.7099 - loss: 0.9489
# Epoch 11/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.9017 - dept_output_accuracy: 0.7012 - loss: 0.9262
# Epoch 12/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.8724 - dept_output_accuracy: 0.7071 - loss: 0.9522
# Epoch 13/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attr_output_accuracy: 0.8841 - dept_output_accuracy: 0.7323 - loss: 0.9092
# Epoch 14/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.9069 - dept_output_accuracy: 0.6916 - loss: 0.9116
# Epoch 15/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attr_output_accuracy: 0.8975 - dept_output_accuracy: 0.7285 - loss: 0.8583
# Epoch 16/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.8810 - dept_output_accuracy: 0.7510 - loss: 0.8597
# Epoch 17/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.9062 - dept_output_accuracy: 0.7362 - loss: 0.8304
# Epoch 18/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.9087 - dept_output_accuracy: 0.7598 - loss: 0.7724
# Epoch 19/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.9172 - dept_output_accuracy: 0.7624 - loss: 0.7414
# Epoch 20/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.9142 - dept_output_accuracy: 0.8028 - loss: 0.7031
# Epoch 21/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attr_output_accuracy: 0.9123 - dept_output_accuracy: 0.7850 - loss: 0.7016
# Epoch 22/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attr_output_accuracy: 0.8928 - dept_output_accuracy: 0.7854 - loss: 0.7020
# Epoch 23/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.9069 - dept_output_accuracy: 0.8250 - loss: 0.6750
# Epoch 24/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.9246 - dept_output_accuracy: 0.8161 - loss: 0.6198
# Epoch 25/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.9153 - dept_output_accuracy: 0.8224 - loss: 0.6420
# Epoch 26/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attr_output_accuracy: 0.
100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - attr_output_accuracy: 0.9850 - dept_output_accuracy: 0.9776 - loss: 0.1094
# Epoch 85/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.9953 - dept_output_accuracy: 0.9809 - loss: 0.0892
# Epoch 86/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attr_output_accuracy: 0.9932 - dept_output_accuracy: 0.9573 - loss: 0.1476
# Epoch 87/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attr_output_accuracy: 0.9929 - dept_output_accuracy: 0.9506 - loss: 0.1682
# Epoch 88/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.9990 - dept_output_accuracy: 0.9468 - loss: 0.1384
# Epoch 89/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attr_output_accuracy: 0.9992 - dept_output_accuracy: 0.9821 - loss: 0.0730
# Epoch 90/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attr_output_accuracy: 0.9998 - dept_output_accuracy: 0.9945 - loss: 0.0399
# Epoch 91/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attr_output_accuracy: 0.9996 - dept_output_accuracy: 0.9988 - loss: 0.0233
# Epoch 92/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attr_output_accuracy: 0.9982 - dept_output_accuracy: 0.9997 - loss: 0.0245
# Epoch 93/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attr_output_accuracy: 0.9985 - dept_output_accuracy: 0.9976 - loss: 0.0293
# Epoch 94/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attr_output_accuracy: 0.9999 - dept_output_accuracy: 0.9999 - loss: 0.0185
# Epoch 95/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - attr_output_accuracy: 0.9992 - dept_output_accuracy: 0.9991 - loss: 0.0191
# Epoch 96/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - attr_output_accuracy: 0.9986 - dept_output_accuracy: 0.9990 - loss: 0.0167
# Epoch 97/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - attr_output_accuracy: 0.9997 - dept_output_accuracy: 0.9991 - loss: 0.0133
# Epoch 98/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.9979 - dept_output_accuracy: 0.9977 - loss: 0.0253
# Epoch 99/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attr_output_accuracy: 0.9969 - dept_output_accuracy: 0.9948 - loss: 0.0249
# Epoch 100/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attr_output_accuracy: 0.9955 - dept_output_accuracy: 0.9949 - loss: 0.0400

# %%
# Evaluate the model with the testing data
results = model.evaluate(X_test_scaled, {'dept_output': dept_y_test_encoded, 'attr_output': attr_y_test_encoded})
results
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - attr_output_accuracy: 0.8218 - dept_output_accuracy: 0.5449 - loss: 5.4363
# [5.697256565093994, 0.83423912525177, 0.5380434989929199]

# %%
# Print the accuracy for both department and attrition
print(f"Loss: {round(results[0],4)}")
print(f"Department predictions accuracy: {round(results[1],4)}")
print(f"Attrition predictions accuracy: {round(results[2],4)}")
# Out:
# Loss: 5.6973
# Department predictions accuracy: 0.8342
# Attrition predictions accuracy: 0.538

# %% [markdown]
# Loss: 4.830270767211914, Attrition Accuracy: 0.83152174949646,Department Accuracy: 0.554347813129425
#
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attr_output_accuracy: 0.8306 - dept_output_accuracy: 0.5387 - loss: 5.9716
# 12/12 - 0s - 7ms/step - attr_output_accuracy: 0.8424 - dept_output_accuracy: 0.5245 - loss: 6.3704
# Loss: 6.370359897613525, Attrition Accuracy: 0.842391312122345,Department Accuracy: 0.5244565010070801

# %% [markdown]
# # Summary
#
# In the provided space below, briefly answer the following questions.
#
# 1. Is accuracy the best metric to use on this data? Why or why not?
#
# 2. What activation functions did you choose for your output layers, and why?
#
# 3. Can you name a few ways that this model might be improved?

# %% [markdown]
# YOUR ANSWERS HERE
#
# 1. Accuracy may not be the best metric on his data because the classes viz. Attrition and Department are not evenly distributed
# 2. I used sigmoid activation function for Attrition and softmax for Department Attrition is binary classification so sigmoid activation was appropriate in my opinion while Department is multi-class classification so I preferred to use softmax activation function where each instance belongs to one department.
# 3.
